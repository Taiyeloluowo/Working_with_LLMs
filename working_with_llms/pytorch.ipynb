# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.2050, 0.7708, 0.2200],
#         [0.2716, 0.3933, 0.8326],
#         [0.4706, 0.4212, 0.4465],
#         [0.2033, 0.8973, 0.2561],
#         [0.0635, 0.4040, 0.5170]])

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
import torch
torch.__version__
# Out:
# '2.9.0+cu126'
